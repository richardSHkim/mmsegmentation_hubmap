# %%
import sys
sys.path.append('../tests')
from tests.test_data.test_transform import test_hubmapaug

# %%
for i in range(100):
    test_hubmapaug(visualize=False)

# %%
test_hubmapaug(visualize=True)
